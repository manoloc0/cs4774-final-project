# %% [markdown]
# <a href="https://colab.research.google.com/github/manoloc0/cs4774-final-project/blob/tyler-local-fips-data/CS4774_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Big Picture
#
# *   **What’s the benefit (use case) for this model?** The main motivation for performing an analysis of EV car charger distribution is to equip proponents of electric vehicle car adoption and infrastructure growth with reliable machine learning model backed data to guide strategic allocation of financial support. By training a machine learning model with a diverse dataset on EV driving ranges, EV car density, and traffic data, we hope to provide a useful application to help substantiate decisions pertaining to optimal locations for new EV chargers. Our problem is that there are many jurisdictions in Virginia that don’t have enough charging stations for long distance trips. We hypothesize that there are optimal locations for new electric vehicle charging station located in less populated areas that should be prioritized during charging station infrastructure planning.
#
# *   **What performance measure?**
# *   **How much data to evaluate?** Data is available on [Drive Electric VA EV Dashboard](https://driveelectricva.org/why-drive-electric/ev-dashboard/#/analyze?region=US-VA&show_map=true&country=US&access=public&access=private&fuel=ELEC&lpg_secondary=true&hy_nonretail=true&ev_levels=all).
#    *   **Station Location Data**: [Download](https://developer.nrel.gov/api/alt-fuel-stations/v1.csv?access=public%2Cprivate&api_key=foEpOo7RpC4gPM41vxhvNB8IQLzek39WVbwjlX5p&cards_accepted=all&cng_fill_type=all&cng_has_rng=all&cng_psi=all&country=US&download=true&e85_has_blender_pump=false&ev_charging_level=all&ev_connector_type=all&ev_network=all&fuel_type=ELEC&funding_sources=all&hy_is_retail=true&limit=all&lng_has_rng=all&lpg_include_secondary=false&maximum_vehicle_class=all&offset=0&owner_type=all&state=US-VA&status=E&utf8_bom=true) **Description:** Electric Charging Stations in Virginia with Zipcode and Longitude & Latitiude data.
#    *   **EV Charging Port Data**: [Download](https://developer.nrel.gov/api/alt-fuel-stations/v1/ev-charging-units.csv?access=public%2Cprivate&api_key=foEpOo7RpC4gPM41vxhvNB8IQLzek39WVbwjlX5p&cards_accepted=all&cng_fill_type=all&cng_has_rng=all&cng_psi=all&country=US&download=true&e85_has_blender_pump=false&ev_charging_level=all&ev_connector_type=all&ev_network=all&fuel_type=ELEC&funding_sources=all&hy_is_retail=true&limit=all&lng_has_rng=all&lpg_include_secondary=false&maximum_vehicle_class=all&offset=0&owner_type=all&state=US-VA&status=E&utf8_bom=true). **Description:** Electric Charging Stations in Virginia with Zipcode and Longitude & Latitiude data. Includes power output by port where each location may have multiple ports and port types.
#    *   **Electric and Hybrid Vehicle Registration by Jurisdiction Data**: [Download](https://driveelectricva.org/wp-content/uploads/2023/07/Virginia-Electric-Vehicle-Hybrid-Electric-Vehicle-Registrations-by-Jurisdiction-2008-2022.xlsx). **Description:** Electric Vehicle ownership data from 2008 - 2022 by jursisdiction (i.e., County or City). Shows total registered EV's, Total Registered Vehicles, Growth Rates, and projections.
# *   **What learning algorithm?** We plan to run DBSCAN (Density-Based Spatial Clustering of Applications with Noise) experiments to find clusters or locations of high need/demand for EV chargers. Specifically we plan to investigate core neighborhoods for the possibility of adding additional chargers to accommodate growing demand/expected projection of electric vehicle adoption. Additionally, isolated clusters or outliers will be investigated as a potential charging "desert". By analyzing the distance to the nearest charging station in relation to typical travel distances and the lowest EV mileage range, we can assess whether installing an additional charging station is essential to prevent the risk of an EV depleting its charge before reaching its destination.
# *   **How much effort to be spent?**

# %%
import pandas as pd
# Scikit-Learn ≥0.20 is required
import sklearn # general ml package

# Common imports
import numpy as np # fundamental package for scientific computing
import os # to run file I/O operation

# to make this notebook's output stable across runs
# any number will do, as long as it is used consistently
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Get Data
# *   Note that we have 2 options for getting data! We can either load pre-merged data or start from scratch.
# *   Load data, get basic statistics, create train & test sets, plot histogram

# %% [markdown]
# **Option 1: Load Pre-merged data.**
# Only run the code cell below to get the already merged data. This is to save API Calls. Skip this step if you want to refetch data, load it, and recaluclate coordinates and charging station numbers. This is only advised for our final training session.

# %%
MERGED_DATA_PATH = os.path.join("datasets")

def load_merged_data(merged_data_path=MERGED_DATA_PATH):
    """Load already merged data from 1000 API Calls"""
    csv_path = os.path.join(merged_data_path, "merged_data_1000.csv")
    return pd.read_csv(csv_path)

merged_df = load_merged_data()

# %%
merged_df
# Out:
#       FIPS  Registered_EVs_2022   Latitude  Longitude  Charging_Stations
# 0    51001                  179  37.764939 -75.756557                  9
# 1    51003                  979  38.022898 -78.556676                 25
# 2    51510                 1444  38.818454 -77.086206                 24
# 3    51005                    9  37.787778 -80.006175                  1
# 4    51007                   12  37.336026 -77.976138                  0
# ..     ...                  ...        ...        ...                ...
# 128  51830                   71  37.269177 -76.707596                  0
# 129  51840                   83  39.173505 -78.174644                  4
# 130  51195                   19  36.975223 -82.621202                  0
# 131  51197                   21  36.917112 -81.078668                  8
# 132  51199                  276  37.238052 -76.442535                 21
#
# [133 rows x 5 columns]

# %% [markdown]
# **Option 2: Fetch, Load, and Calculate Data From Scratch.** Run the remaining cells if you want to recalculate data from scratch. This is only recommended for our final training session.

# %% [markdown]
# **Fetch Data**

# %%
# Get EV Registration Data, EV Charging Station Data, and

from six.moves import urllib
# URLs for datasets
EV_CHARGING_UNITS_URL = "https://developer.nrel.gov/api/alt-fuel-stations/v1/ev-charging-units.csv?access=public%2Cprivate&api_key=foEpOo7RpC4gPM41vxhvNB8IQLzek39WVbwjlX5p&cards_accepted=all&cng_fill_type=all&cng_has_rng=all&cng_psi=all&country=US&download=true&e85_has_blender_pump=false&ev_charging_level=all&ev_connector_type=all&ev_network=all&fuel_type=ELEC&funding_sources=all&hy_is_retail=true&limit=all&lng_has_rng=all&lpg_include_secondary=false&maximum_vehicle_class=all&offset=0&owner_type=all&state=US-VA&status=E&utf8_bom=true"
EV_REGISTRATIONS_URL = "https://driveelectricva.org/wp-content/uploads/2023/07/Virginia-Electric-Vehicle-Hybrid-Electric-Vehicle-Registrations-by-Jurisdiction-2008-2022.xlsx"

# Paths to save the files
EV_CHARGING_PATH = os.path.join("datasets", "ev_charging_units")
EV_REGISTRATIONS_PATH = os.path.join("datasets", "ev_registrations")

def fetch_data():
    """Fetch both EV charging and EV registration data to the local file system."""

    # Download EV Charging Data
    if not os.path.isdir(EV_CHARGING_PATH):
        os.makedirs(EV_CHARGING_PATH)
    csv_path = os.path.join(EV_CHARGING_PATH, "ev_charging_units.csv")
    urllib.request.urlretrieve(EV_CHARGING_UNITS_URL, csv_path)
    print("EV Charging data downloaded and saved to:", csv_path)

    # Download EV Registrations Data
    if not os.path.isdir(EV_REGISTRATIONS_PATH):
        os.makedirs(EV_REGISTRATIONS_PATH)
    xlsx_path = os.path.join(EV_REGISTRATIONS_PATH, "Virginia_EV_Registrations.xlsx")
    urllib.request.urlretrieve(EV_REGISTRATIONS_URL, xlsx_path)
    print("EV Registrations data downloaded and saved to:", xlsx_path)

fetch_data()
# Out:
# EV Charging data downloaded and saved to: datasets/ev_charging_units/ev_charging_units.csv
# EV Registrations data downloaded and saved to: datasets/ev_registrations/Virginia_EV_Registrations.xlsx

# %% [markdown]
# **Load Data**

# %%
import json

EV_CHARGING_PATH = os.path.join("datasets", "ev_charging_units")
EV_REGISTRATIONS_PATH = os.path.join("datasets", "ev_registrations")

def load_ev_charging_data(ev_charging_path=EV_CHARGING_PATH):
    """Load EV Charging Stations Data into Workspace from a CSV file."""
    csv_path = os.path.join(ev_charging_path, "ev_charging_units.csv")
    return pd.read_csv(csv_path)

def load_fips_data():
    with open('/content/fips_coordinate_data.json') as f:
      return json.load(f)

def load_ev_registrations_data(ev_registrations_path=EV_REGISTRATIONS_PATH):
    """Load EV Registrations Data into Workspace from an Excel file starting at cell B3."""
    xlsx_path = os.path.join(ev_registrations_path, "Virginia_EV_Registrations.xlsx")
    return pd.read_excel(xlsx_path, skiprows=2, nrows = 133, usecols="B:R")  # Adjust "B:Z" as needed to match your column range

# Load the EV charging station, fips, and EV registration data
ev_charging = load_ev_charging_data()
fips_data = load_fips_data()
ev_registrations = load_ev_registrations_data()

# Cull all data from registrations except for FIPS and 2022
ev_registrations_2022 = ev_registrations[["FIPS",2022]] # from reg

# %% [markdown]
# **Add Coordinate Data based on FIPS**

# %%
mid_lati = []
mid_longi = []
count = np.empty(132)

# Convert JSON data into a dictionary for easy lookup by FIPS code
fips_coordinates = {item["geoid"]: item["geo_point_2d"] for item in fips_data["results"]}

# Sample list of FIPS codes to retrieve coordinates
mid_lati = []
mid_longi = []
fips_list = []

for i in range(len(ev_registrations_2022)):
    query_fips = str(ev_registrations_2022.loc[i, "FIPS"])
    coordinate = fips_coordinates.get(query_fips)
    if coordinate:
        fips_list.append(query_fips)
        mid_lati.append(coordinate['lat'])
        mid_longi.append(coordinate['lon'])
    else:
        print(f"Coordinates for FIPS {query_fips} not found in JSON data")

# Create the DataFrame
coordinates_df = pd.DataFrame({
    'FIPS': fips_list,
    'Latitude': mid_lati,
    'Longitude': mid_longi
})

# Merge EV Registration Data with Coordinate Data
ev_registrations_2022['FIPS'] = ev_registrations_2022['FIPS'].astype(str)
merged_df = ev_registrations_2022.merge(coordinates_df, on="FIPS", how="left")
merged_df = merged_df.rename(columns={2022: 'Registered_EVs_2022'})
# Out:
# <ipython-input-13-9030929a7880>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_registrations_2022['FIPS'] = ev_registrations_2022['FIPS'].astype(str)

# %% [markdown]
# **Calculate Number of Charging Stations for each Jurisdiction**

# %%
# Sum the number of charging stations within each FIPS (aka Jurisdiction) based on Zip Code of the charging station
import requests
ev_charging = ev_charging.head(1000)
merged_df['EV_Charging_Stations'] = 0

for idx, row in ev_charging.iterrows():
    zip_code = row['ZIP']
    api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..WQ5eHhsgGhjZPqW0kmIN-Bf-nPnJ97VliErhDmcqNrRZ-PA81V7gkVGI2PmYVtX51gLvv61WltjqESd7Pso6rA"
    zip_url = f"https://www.huduser.gov/hudapi/public/usps?type=1&query={zip_code}"

    headers = {
        "Authorization": f"Bearer {api_key}"
    }

    # Make the API call with the headers
    zip_response = requests.get(zip_url, headers=headers)


    if zip_response.status_code == 200:
        fips = (zip_response.json()['data']['results'][0]['geoid'])[:5]
        print(fips)
        # Use .loc to access and update the 'EV_Charging_Stations' column based on the FIPS value
        merged_df.loc[merged_df['FIPS'] == fips, 'EV_Charging_Stations'] += ev_charging.loc[idx, "EV J1772 Connector Count"]
        merged_df.loc[merged_df['FIPS'] == fips, 'EV_Charging_Stations'] += ev_charging.loc[idx, "EV CCS Connector Count"]
        merged_df.loc[merged_df['FIPS'] == fips, 'EV_Charging_Stations'] += ev_charging.loc[idx, "EV CHAdeMO Connector Count"]
        merged_df.loc[merged_df['FIPS'] == fips, 'EV_Charging_Stations'] += ev_charging.loc[idx, "EV J3400 Connector Count"]
    else:
        print(f"Error: {zip_response.status_code}")

merged_df.head(132)
merged_df.to_csv('merged_data.csv', index=False)
# Out:
# 51063
# 51510
# 51510
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-562cb3ed861b> in <cell line: 6>()
#      14
#      15     # Make the API call with the headers
# ---> 16     zip_response = requests.get(zip_url, headers=headers)
#      17
#      18
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %% [markdown]
# **IMPORTANT: Use Code Below to Skip Fetching & Loading Steps.** This is so we don't overuse API calls.

# %%
#Tyler TO DO: Create train & test sets, plot histogram

# %% [markdown]
# #  Step 3: Discover & Visualize Data
# *   Plot, use opacity, use color & sizes, add image, Look at correlations, isolate interesting one Experiment w/ feature extraction (e.g., total # of rooms?)

# %%
# TO DO: Visualize Data

# %% [markdown]
# # Step 4: Prepare data (data cleaning)
#
# *   Detect & fill missing values, fill in w/ Imputer, Transform training set (ie, change raw data)
# *   Pipeline for a sequence of transformations (e.g., detect/fill missing values, process categorical inputs, scale features in one pipeline)
# *   Process categorical inputs (one-hot encoding)
# *   Combine Columns (num-attributes & cat-attributes)

# %%
# Obsolete
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import pandas as pd

# Check for missing values
print(ev_charging.isnull().sum())
print(ev_registrations.isnull().sum())

# Charging
# numeric and categorical columns
num_attributes = ev_charging.select_dtypes(include=['float64', 'int64']).columns.tolist()
cat_attributes = ev_charging.select_dtypes(include=['object']).columns.tolist()

# Numeric pipeline
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Categorical pipeline
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Full pipeline
preprocessing_pipeline = ColumnTransformer(
    transformers=[
        ('num', num_pipeline, num_attributes),
        ('cat', cat_pipeline, cat_attributes)
    ])

# Apply the pipeline to the EV charging dataset
ev_charging_prepared = preprocessing_pipeline.fit_transform(ev_charging)



#registration
ev_registrations.columns = ev_registrations.columns.astype(str)

# Separate numeric and categorical columns
num_attributes_reg = ev_registrations.select_dtypes(include=['float64', 'int64']).columns.tolist()
cat_attributes_reg = ev_registrations.select_dtypes(include=['object']).columns.tolist()

# Display columns for verification
print("Numeric columns:", num_attributes_reg)
print("Categorical columns:", cat_attributes_reg)

# Numeric pipeline
num_pipeline_reg = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Categorical pipeline
cat_pipeline_reg = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Full pipeline
preprocessing_pipeline_reg = ColumnTransformer([
    ('num', num_pipeline_reg, num_attributes_reg),
    ('cat', cat_pipeline_reg, cat_attributes_reg)
])

# Apply the pipeline to the EV registrations dataset
try:
    ev_registrations_prepared = preprocessing_pipeline_reg.fit_transform(ev_registrations)
    print("Pipeline applied successfully.")
except Exception as e:
    print("Error encountered:", e)
# Out:
# Fuel Type Code                     0
# Station Name                       0
# Street Address                     0
# Intersection Directions         4292
# City                               0
#                                 ...
# EV CCS Power Output (kW)        4560
# EV CHAdeMO Connector Count         0
# EV CHAdeMO Power Output (kW)    4803
# EV J3400 Connector Count           0
# EV J3400 Power Output (kW)      4654
# Length: 83, dtype: int64
# FIPS            1
# Jurisdiction    3
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            9
# 2019            0
# 2020            0
# 2021            1
# 2022            1
# dtype: int64
# Numeric columns: ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
# Categorical columns: ['FIPS', 'Jurisdiction', '2008', '2009', '2010', '2011', '2012', '2013', '2014']
# ...

# %% [markdown]
# # Step 5: Select model to train
#
#
# *   Select model (eg: Linear Regression, DecisionTreeRegressor, RandomForrest)
# *   Evaluate on some data (pipelined)
# *   Calculate errors (eg MSE, RMSE)
# *   Cross-validation scores (outputs array)
# *   Display score data (Scores, mean, standard deviation)

# %%
# -------- Start API Call Version --------

# %%
# get coordinates
# for i in range(len(ev_registrations_2022)):
for i in range(4):
    query_fips = ev_registrations_2022.loc[i,"FIPS"]
    print(query_fips)
    fips_url = f"https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/us-county-boundaries/records?limit=20&countyfp_nozero={query_fips}"
    fips_response = requests.get(fips_url)
    if fips_response.status_code == 200:
        coordinate = fips_response.json()['results'][0]['geo_point_2d']
        print(coordinate)
        # print(coordinate)
        mid_lati.append(coordinate['lat'])
        mid_longi.append(coordinate['lon'])
    else:
        print(f"Error: {fips_response.status_code}")
# Out:
# 51001
# {'lon': -79.2360118434, 'lat': 41.5130724363}
# 51003
# {'lon': -79.2360118434, 'lat': 41.5130724363}
# 51510
# {'lon': -79.2360118434, 'lat': 41.5130724363}
# 51005
# {'lon': -79.2360118434, 'lat': 41.5130724363}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Save to locally
mid_lati = pd.DataFrame(mid_lati)
mid_longi = pd.DataFrame(mid_longi)
latitude_path = 'latitude.csv'
longitude_path = 'longitude.csv'
mid_lati.to_csv('latitude.csv', index=False)
mid_longi.to_csv('longitude.csv', index=False)
print("Latitude data downloaded and saved to:", latitude_path)
print("Longitude data downloaded and saved to:", longitude_path)
ev_latitudes = pd.read_csv(latitude_path)
ev_longitudes = pd.read_csv(longitude_path)
# print(ev_latitudes.head(20))
# print(ev_longitudes.head(20))
# Out:
# Latitude data downloaded and saved to: latitude.csv
# Longitude data downloaded and saved to: longitude.csv

# %%
# get connector count
ev_charging = ev_charging.head(50)
for idx, row in ev_charging.iterrows():
    zip_code = row['ZIP']
    api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..WQ5eHhsgGhjZPqW0kmIN-Bf-nPnJ97VliErhDmcqNrRZ-PA81V7gkVGI2PmYVtX51gLvv61WltjqESd7Pso6rA"
    zip_url = f"https://www.huduser.gov/hudapi/public/usps?type=1&query={zip_code}"

    headers = {
        "Authorization": f"Bearer {api_key}"
    }

    # Make the API call with the headers
    zip_response = requests.get(zip_url, headers=headers)

    if zip_response.status_code == 200:
        fips = (zip_response.json()['data']['results'][0]['geoid'])[:5]
        fips_idx = ev_registrations.index[ev_registrations_2022['FIPS'] == fips] #fips idx
        # ev_registrations_2022.loc[ev_registrations_2022['FIPS'] == fips, 2022] += 1
        #bbox = response.json()['results'][0]['bbox']
        #midpoint = [(bbox[0] + bbox[2]) / 2, (bbox[1] + bbox[3]) / 2]
        #mid_lati.append(midpoint[0])
        #mid_longi.append(midpoint[1])
        count[fips_idx] += ev_charging["EV J1772 Connector Count"].loc[idx]
        count[fips_idx] += ev_charging["EV CCS Connector Count"].loc[idx]
        count[fips_idx] += ev_charging["EV CHAdeMO Connector Count"].loc[idx]
        count[fips_idx] += ev_charging["EV J3400 Connector Count"].loc[idx]
        # ev_charging.loc[x, 'mid_x'] = mid_x
        # ev_charging.loc[x, 'mid_y'] = mid_y
    else:
        print(f"Error: {zip_response.status_code}")

# concatenate new columns
ev_registrations_2022[count] = count

print(ev_registrations_2022.head(20))
# Out:
#      FIPS    2022   latitude  longitude            0.0            0.0  \
# 0   51001   179.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 1   51003   979.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 2   51510  1444.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 3   51005     9.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 4   51007    12.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 5   51009    44.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 6   51011     3.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 7   51013  2479.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 8   51015   146.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 9   51017    11.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 10  51019   167.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# 11  51021     4.0  41.513072 -79.236012  6.842910e-310  4.652524e-310
# ...

# %%
from math import *
from decimal import Decimal
from sklearn.cluster import KMeans
import sys
import numpy as np
m = ev_registrations_2022.shape[0]
#tolerance = 0.5
max_iter = 100

def distance(x, y, p_value):
  x = np.array(x)
  y = np.array(y)
  return np.power(np.sum(np.abs(x - y) ** p_value), 1 / p_value)

def kMeans(dataset,k):
  # initialize
  centroids = initialize_centroids(k, dataset)
  old_centroids = centroids.copy()
  iter = 0

  while iter < max_iter:
    # assign points
    old_centroids = centroids.copy()
    clusters = assign_points(dataset, centroids)
    # recalc clusters
    centroids = recalc_clusters(dataset, clusters, k)
    iter += 1
    #print("iteration:", iter)

    if np.all(old_centroids == centroids):
      break
  return centroids, clusters

def initialize_centroids(k, dataset):
  rand_idx = np.random.choice(len(ev_registrations_2022), size=k,replace = False)
  centroids = [ev_registrations_2022.iloc[idx].values for idx in rand_idx]
  return centroids

def assign_points(dataset, centroids):
  clusters = [[] for i in range(len(centroids))]
  for x in ev_registrations_2022:
    dists = [(distance(x, cent, 2)) for cent in centroids]
    idx = np.argmin(dists)
    clusters[idx].append(x)
  return clusters

def recalc_clusters(assigned_points, clusters, k):
  new_centroids = []
  for cluster in clusters:
      if len(cluster) > 0:
        new_centroids.append(np.mean(cluster, axis=0))
      else:
        new_centroids.append(np.zeros_like(centroids[0]))
  return np.array(new_centroids)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
ks = range(2,11)
#ks = range(2,9)
#ks= [2]
colors = ['r','b','g','c','m','y','k','w',"purple","orange"]
clust_means = []
clust_stds = []
all_sse = []

def mean_std(dataset, clusters):
  clust_means = []
  clust_stds = []
  sse = 0
  for idx, cluster in enumerate(clusters):
    points = np.array(cluster)
    if len(points) > 0:
      sse += np.sum((np.linalg.norm(points - centroids[idx], axis=1)**2))
      clust_means.append(np.mean(points, axis=0))
      clust_stds.append(np.std(points, axis=0))
    else:
        clust_means.append(np.zeros(dataset.shape[1]))
        clust_stds.append(np.zeros(dataset.shape[1]))
  all_sse.append(sse)
  print("cluster means:", clust_means)
  print("cluster stds:", clust_stds)

def get_sse(centroids, clusters):
  sse = 0
  for idx, cluster in enumerate(clusters):
      points = np.array(cluster)
      if len(points) > 0:
          #sse += np.sum(math.pow(np.linalg.norm(points - centroids[idx], axis=1),2))
          sse += np.sum((np.linalg.norm(points - centroids[idx], axis=1)**2))
  print("SSE for 2 clusters:", sse)

for i in ks:
  print("k:", i)
  centroids, clusters = kMeans(ev_registrations_2022,i)
  mean_std(ev_registrations_2022, clusters)
  if i == 2:
    # sse for 2 clusters
    get_sse(centroids, clusters)

  for idx, cluster in enumerate(clusters):
    points = np.array(cluster)
    if points.size > 0:
          plt.scatter(points[:, 0], points[:, 1],
            c=[colors[idx]] * len(points), label=f'Cluster {idx + 1}')
    print()
    print()

  centroids = np.array(centroids)
  plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='y', marker='X', label='Centroids')

  plt.title('K-Means Clustering')
  # plt.plot(X[y_pred==0, 2], X[y_pred==0, 3], color[i])
  plt.xlabel("logitude", fontsize=14)
  plt.ylabel("latitude", fontsize=14)
  plt.legend(loc="upper left", fontsize=12)
  plt.show()


# sse plot
plt.plot(ks, all_sse, marker='o')
plt.xlabel('Num of clusters')
plt.ylabel('SSE')
plt.show()

# %% [markdown]
# # Step 6: Fine-Tuning your Model
# *   Grid Search: hyperparameter optimization technique via combining each possible configuration (e.g., n_estimators & num_features). Computationally expensive. Identify best score (e.g., lowest error) & associate hyperparameters

# %% [markdown]
# # Step 7: Presenting your solution
#
# *   Evaluate model on Test Set (drop label)
# *   Prepare test set w/ pipeline
# *   Find final error (eg: MSE, RMSE, etc)
